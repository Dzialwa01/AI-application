# %%
# Dzialwa Nemakonde
# 28 May 2026

# %%
# Building a text generation pipeline

# Hugging Face pipelines make it simple to use machine learning models for a variety of tasks. In this exercise, you'll build a text generation pipeline using the gpt2 model and customize the output by adjusting its parameters.

# Instructions:
# - Complete the missing code to build a text generation pipeline using the `"gpt2"` model.
# - Provide a custom sentence of your choice as the input prompt; keep it short to prevent timeouts.
# - Configure the pipeline to generate up to 10 tokens and produce 2 outputs.

# %%
from transformers import pipeline

gpt2_pipeline = pipeline(
    task="text-generation", 
    model="openai-community/gpt2"
    )

# Generating three text outputs with a maximum length of 10 tokens
results = gpt2_pipeline(
    "What if AI", 
    )

print(results)
# for result in results:
#     print(result['generated_text'])
# Out:
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 1281.66it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'What if AI could learn to read your brain differently? That\'s the promise of AI, and we\'re still in the early stages of that development process. We\'ve already reached the point where we can say that AI can learn to read brain data and not be able to read specific parts of it.\n\nBut we\'re still in the early stages. We\'re still at the point where a "human" can learn to read and learn to navigate in a way that can be tailored to how we use our brain. That\'s still a long way off.\n\nIn the meantime, we\'re looking to have more AI researchers studying deep learning in the next few years.\n\nAnd if you want to know more about the future of deep learning, check out our Deep Learning series, which covers topics like deep learning and machine learning.\n\nHow do you see AI gaining acceptance as a science?\n\nI think there\'s a lot of room for AI to become a part of science. And that\'s because the technology we\'re using today is so fast and so advanced. But I think there\'s a lot of room for it to grow its power. I think that the future of AI is going to be about how we use it to gain acceptance.\n\nYou mentioned in your'}]
